# %% [markdown]
# ## DataFrames and Dataset

# %%
import pandas as pd

# %%
states_data_path = "DataAnalysis/data/states.csv"
df_states = pd.read_csv(states_data_path)
display(df_states.head())
# Out:
#         State  Abbrev Code
# 0     Alabama    Ala.   AL
# 1      Alaska  Alaska   AK
# 2     Arizona   Ariz.   AZ
# 3    Arkansas    Ark.   AR
# 4  California  Calif.   CA

# %%
kc_house_data_path = "DataAnalysis/data/kc_house_data.csv"
df_kc_house = pd.read_csv(kc_house_data_path)
display(df_kc_house.head())
df_kc_house.info()
df_kc_house.describe()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
type(df_kc_house)
print(df_kc_house.columns)
df_kc_house.index
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')
# RangeIndex(start=0, stop=21613, step=1)

# %%
df_kc_house['price'][0:10]
# Out:
# 0     221900.0
# 1     538000.0
# 2     180000.0
# 3     604000.0
# 4     510000.0
# 5    1225000.0
# 6     257500.0
# 7     291850.0
# 8     229500.0
# 9     323000.0
# Name: price, dtype: float64

# %%
len(df_kc_house)
# Out:
# 21613

# %%
df_kc_house.shape
# Out:
# (21613, 21)

# %%
df_kc_house.size
# Out:
# 453873

# %%
df_kc_house.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
df_kc_house.tail(10)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21603  7852140040  20140825T000000   507250.0         3       2.50
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21603         2270      5536     2.0           0     0  ...      8
# 21604         1490      1126     3.0           0     0  ...      8
# ...

# %%
df_kc_house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
data_neflix = "DataAnalysis/data/netflix_titles.csv"
df_Neflix = pd.read_csv(data_neflix, sep="|", index_col=0)
df_Neflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df_Neflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 894.5+ KB

# %% [markdown]
# ### Overwrite collumn's name

# %%
data_nst_est2020 = "DataAnalysis/data/nst-est2020.csv"
names=["state", "name", "census", "estimates_base", 
        "pop_2010", "pop_2011", "pop_2012", 
        "pop_2013", "pop_2014", "pop_2015", 
        "pop_2016", "pop_2017", "pop_2018", 
        "pop_2019", "pop_042020", "pop_2020"]
df_nst_est2020 = pd.read_csv(data_nst_est2020, names=names, header=1) 
df_nst_est2020.head()
# Out:
#         state              name     census  estimates_base   pop_2010  \
# 20 1 0      0  Northeast Region   55317240        55318414   55380764
#    2 0      0    Midwest Region   66927001        66929737   66975328
#    3 0      0      South Region  114555744       114563042  114869421
#    4 0      0       West Region   71945553        71946912   72101630
# 40 3 6      1           Alabama    4779736         4780118    4785514
#
#          pop_2011   pop_2012   pop_2013   pop_2014   pop_2015   pop_2016  \
# 20 1 0   55608318   55782661   55912775   56021339   56052790   56063777
#    2 0   67164092   67348275   67576524   67765576   67885682   68018175
#    3 0  116019483  117264196  118397213  119666248  121049223  122419547
#    4 0   72791588   73482530   74173435   74933166   75751299   76570256
# 40 3 6    4799642    4816632    4831586    4843737    4854803    4866824
#
#          pop_2017   pop_2018   pop_2019  pop_042020   pop_2020
# ...

# %% [markdown]
# ### Excercise1

# %%
# Part 1 
# Read the bestsellers dataset into a DataFrame
bestsellers_path = "DataAnalysis/data/bestsellers.csv"
bestsellers = pd.read_csv(bestsellers_path)
bestsellers.head()
# How many rows and columns does the dataset have?
bestsellers.shape
# Which columns have missing values?
bestsellers.isnull().sum()
# What data type is each column?
bestsellers.dtypes
# How many integer columns are in the dataset?
bestsellers.select_dtypes(include='int64').shape[1]
# Out:
# 3

# %%
# Part 2
# The mount_everest_deaths dataset contains information about the number of deaths on Mount Everest from 1922 to 2019.
# When importing it, use the existing index column.
# Which columns have zero null values?
mount_everest_deaths_path = "DataAnalysis/data/mount_everest_deaths.csv"
mount_everest_deaths = pd.read_csv(mount_everest_deaths_path, index_col=0)
mount_everest_deaths.isnull().sum()
# Out:
# Name                0
# Date                0
# Age               150
# Expedition         39
# Nationality         1
# Cause of death     14
# Location           19
# dtype: int64

# %%
# Part 3
# Import the movie_titles.tsv dataset
# You'll notice that it is not comma-separated! You'll need to specify the separator when importing it.
data_movie_titles = "DataAnalysis/data/movie_titles.tsv"
names = ["ID", "title", "year", "imdb_rating", "imdb_id", "genres"]
movie_titles = pd.read_csv(data_movie_titles, sep="\t", names=names)
display(movie_titles.head())
display(movie_titles.tail(7))
# Out:
#    ID                       title  year  imdb_rating   imdb_id  \
# 0  m0  10 things i hate about you  1999          6.9   62847.0
# 1  m1  1492: conquest of paradise  1992          6.2   10421.0
# 2  m2                  15 minutes  2001          6.1   25854.0
# 3  m3       2001: a space odyssey  1968          8.4  163227.0
# 4  m4                     48 hrs.  1982          6.9   22289.0
#
#                                            genres
# 0                            ['comedy' 'romance']
# 1     ['adventure' 'biography' 'drama' 'history']
# 2           ['action' 'crime' 'drama' 'thriller']
# 3                ['adventure' 'mystery' 'sci-fi']
# 4  ['action' 'comedy' 'crime' 'drama' 'thriller']
#        ID                    title  year  imdb_rating   imdb_id  \
# 610  m610         the wizard of oz  1939          8.3  104873.0
# 611  m611  the world is not enough  1999          6.3   60047.0
# 612  m612                 watchmen  2009          7.8  135229.0
# ...

# %% [markdown]
# ## Basic DataFrame Method and Multipulate

# %% [markdown]
# ### Min & Max, sum, mean, ......

# %%
import pandas as pd

data_house = "DataAnalysis/data/kc_house_data.csv"
df_house = pd.read_csv(data_house)
df_house.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
#show 3 columns price and bedrooms and bathrooms
df_house["price"].describe()
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
df_house.sum(numeric_only=True)
# Out:
# id               9.899406e+13
# price            1.167293e+10
# bedrooms         7.285400e+04
# bathrooms        4.570625e+04
# sqft_living      4.495287e+07
# sqft_lot         3.265069e+08
# floors           3.229650e+04
# waterfront       1.630000e+02
# view             5.064000e+03
# condition        7.368800e+04
# grade            1.654880e+05
# sqft_above       3.865249e+07
# sqft_basement    6.300385e+06
# yr_built         4.259933e+07
# yr_renovated     1.824186e+06
# zipcode          2.119759e+09
# lat              1.027915e+06
# long            -2.641409e+06
# sqft_living15    4.293536e+07
# sqft_lot15       2.759646e+08
# dtype: float64

# %%
df_house.count()
# Out:
# id               21613
# date             21613
# price            21613
# bedrooms         21613
# bathrooms        21613
# sqft_living      21613
# sqft_lot         21613
# floors           21613
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21613
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# dtype: int64

# %%
df_house.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64
